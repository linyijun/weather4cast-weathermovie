# %%
import torch
a = torch.randn((3, 4, 32, 7, 7))
print(a.shape)
# Out:
# torch.Size([3, 4, 32, 7, 7])

# %%
torch.arange(0, 4).unsqueeze(0).shape
# Out:
# torch.Size([1, 4])

# %%
pos_embedding = torch.nn.Embedding(16, embedding_dim=32)

b = torch.arange(0, 4).unsqueeze(0).unsqueeze(-1).unsqueeze(-1)

b = b.repeat(3, 1, 7, 7)

b = pos_embedding(b)

print(b.shape)#.repeat(256, 2)#.unsqueeze(-1).repeat(256, -1)
# Out:
# torch.Size([3, 4, 7, 7, 32])

# %%
pos_embedding(b)
# Out:
# tensor([[[[[-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            ...,
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946]],
#
#           [[-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            ...,
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946],
#            [-2.3161,  0.3533, -0.2898,  ...,  0.0860,  1.2193, -0.3946]],
#
# ...
